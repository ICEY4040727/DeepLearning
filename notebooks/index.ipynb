# %% [raw]
# {
#   "cells": [
#     {
#       "cell_type": "markdown",
#       "metadata": {},
#       "source": [
#         "# 项目导航（Notebooks 索引）\n",
#         "\n",
#         "欢迎！本页面将作为 GitHub Pages 的首页（docs/index.html），汇总 `notebooks/` 目录下的 Notebook。\n",
#         "\n",
#         "说明：\n",
#         "- 本仓库的 CI 会将 `notebooks/` 下的 `.ipynb` 转换为 HTML 并保留目录结构到 `docs/`。\n",
#         "- 若你的 Notebook 存在多层子目录，例如：\n",
#         "  `notebooks/exp1/classification/mnist_cnn.ipynb`\n",
#         "  则发布后的页面地址为：\n",
#         "  `/DeepLearning/exp1/classification/mnist_cnn.html`\n",
#         "- 本页面提供两类目录：\n",
#         "  1) 网页浏览（HTML 链接）\n",
#         "  2) 在 Jupyter/Binder 中打开原始 `.ipynb`（交互式运行）\n",
#         "\n",
#         "使用方式：\n",
#         "- 你可以手工在下面的“目录（网页浏览）/目录（Jupyter）”中添加链接；\n",
#         "- 或者运行文末的“生成目录 Markdown（可选）”代码单元，把输出复制到“自动生成目录（粘贴输出到这里）”位置，以便在 Pages 显示静态目录。"
#       ]
#     },
#     {
#       "cell_type": "markdown",
#       "metadata": {},
#       "source": [
#         "## 目录（网页浏览：HTML 链接）\n",
#         "\n",
#         "示例（请按你的实际结构修改或用自动生成替换）：\n",
#         "\n",
#         "- 实验 1（Classification）\n",
#         "  - [exp1/classification/mnist_cnn.html](exp1/classification/mnist_cnn.html)\n",
#         "  - [exp1/classification/cifar_resnet.html](exp1/classification/cifar_resnet.html)\n",
#         "- 实验 2（Segmentation）\n",
#         "  - [exp2/segmentation/unet_baseline.html](exp2/segmentation/unet_baseline.html)\n",
#         "  - [exp2/segmentation/unet_plus_plus.html](exp2/segmentation/unet_plus_plus.html)"
#       ]
#     },
#     {
#       "cell_type": "markdown",
#       "metadata": {},
#       "source": [
#         "## 目录（Jupyter/Binder：原始 .ipynb 链接）\n",
#         "\n",
#         "在本地或 Binder 中点击这些链接可直接打开 Notebook（注意：在 GitHub Pages 上点击 `.ipynb` 通常会下载或在 GitHub 前端查看，不会在浏览器交互运行）：\n",
#         "\n",
#         "- 实验 1（Classification）\n",
#         "  - [exp1/classification/mnist_cnn.ipynb](exp1/classification/mnist_cnn.ipynb)\n",
#         "  - [exp1/classification/cifar_resnet.ipynb](exp1/classification/cifar_resnet.ipynb)\n",
#         "- 实验 2（Segmentation）\n",
#         "  - [exp2/segmentation/unet_baseline.ipynb](exp2/segmentation/unet_baseline.ipynb)\n",
#         "  - [exp2/segmentation/unet_plus_plus.ipynb](exp2/segmentation/unet_plus_plus.ipynb)"
#       ]
#     },
#     {
#       "cell_type": "markdown",
#       "metadata": {
#         "tags": [
#           "auto-generated-placeholder"
#         ]
#       },
#       "source": [
#         "## 自动生成目录（粘贴输出到这里）\n",
#         "\n",
#         "> 可选：运行下方代码单元，它会扫描 `notebooks/` 下的所有 `.ipynb`（跳过本文件），并生成两段 Markdown：\n",
#         "> 1) 网页浏览（HTML 链接） 2) Jupyter/Binder（.ipynb 链接）。\n",
#         "> 将生成的 Markdown 复制粘贴到此处，提交后 GitHub Pages 将展示静态目录。\n",
#         "\n",
#         "_（占位区，粘贴你自动生成的目录内容到这里）_"
#       ]
#     },
#     {
#       "cell_type": "code",
#       "execution_count": null,
#       "metadata": {
#         "tags": [
#           "generate-toc"
#         ]
#       },
#       "outputs": [],
#       "source": [
#         "# 生成目录 Markdown（可选）\n",
#         "# 运行后会打印两段 Markdown：\n",
#         "# 1) 网页浏览（HTML 链接） 2) Jupyter/Binder（.ipynb 链接）\n",
#         "# 说明：请在仓库根目录启动 Jupyter（working dir 为仓库根），\n",
#         "# 这样此脚本中的 Path('notebooks') 才能正确找到目录。\n",
#         "\n",
#         "from pathlib import Path\n",
#         "\n",
#         "base = Path('notebooks')\n",
#         "assert base.exists(), \"未找到 notebooks/ 目录，请在仓库根目录启动 Jupyter 或检查路径。\"\n",
#         "\n",
#         "files = sorted([p for p in base.rglob('*.ipynb') if p.name.lower() != 'index.ipynb'])\n",
#         "if not files:\n",
#         "    print(\"未发现除 index.ipynb 外的 .ipynb 文件。\")\n",
#         "else:\n",
#         "    def make_lines(ext: str):\n",
#         "        lines = []\n",
#         "        for p in files:\n",
#         "            rel = p.relative_to(base)\n",
#         "            depth = len(rel.parts) - 1  # 缩进深度\n",
#         "            name = rel.stem\n",
#         "            link = rel.with_suffix(ext).as_posix()\n",
#         "            lines.append(\"  \" * depth + f\"- [{name}]({link})\")\n",
#         "        return lines\n",
#         "\n",
#         "    html_lines = make_lines('.html')\n",
#         "    ipynb_lines = make_lines('.ipynb')\n",
#         "\n",
#         "    print(\"## 目录（网页浏览：HTML 链接）\\n\")\n",
#         "    print(\"\\n\".join(html_lines))\n",
#         "    print(\"\\n\\n## 目录（Jupyter/Binder：原始 .ipynb 链接）\\n\")\n",
#         "    print(\"\\n\".join(ipynb_lines))\n",
#         "\n",
#         "    print(\"\\n\\n提示：将上述两段 Markdown 全部复制，粘贴到“自动生成目录（粘贴输出到这里）”占位区，然后保存并提交。\")"
#       ]
#     },
#     {
#       "cell_type": "markdown",
#       "metadata": {},
#       "source": [
#         "## 常见问题（FAQ）\n",
#         "\n",
#         "- 为什么网页首页（GitHub Pages）看不到我用代码单元生成的目录输出？\n",
#         "  - 因为默认 CI 只“转换”而不“执行” Notebook。请将生成的目录 Markdown 文本复制到上面的占位区（一个 Markdown 单元格），提交后即可在 Pages 显示。\n",
#         "- 我可以让 CI 自动执行 index.ipynb 并保留输出吗？\n",
#         "  - 可以，但不推荐对包含深度学习依赖的 Notebook 启用执行（时间长/易失败）。\n",
#         "  - 如果只想保留 index.ipynb 的输出，可在 `.pre-commit-config.yaml` 中为 nbstripout 添加 `exclude: ^notebooks/index.ipynb$`，避免清理此文件的输出。（此做法需你确认团队规范。）\n",
#         "- 链接规则如何记忆？\n",
#         "  - 对于 `notebooks/` 下的 `a/b/c.ipynb`，网页 HTML 链接是 `a/b/c.html`；Jupyter/Binder 链接是 `a/b/c.ipynb`。"
#       ]
#     }
#   ],
#   "metadata": {
#     "kernelspec": {
#       "display_name": "Python 3",
#       "language": "python",
#       "name": "python3"
#     },
#     "language_info": {
#       "name": "python",
#       "version": "3.10"
#     }
#   },
#   "nbformat": 4,
#   "nbformat_minor": 5
# }
