# %% [markdown]
# # 项目导航（Notebooks 索引）
#
# 欢迎！本页面将作为 GitHub Pages 的首页。
#
# ## 快速开始
#
# - [在 Binder 中运行](https://mybinder.org/v2/gh/ICEY4040727/DeepLearning/master)
# - [在 Colab 中打开](https://colab.research.google.com/github/ICEY4040727/DeepLearning/blob/master/notebooks/)
#
# ## Notebook 列表
#
# _（在这里添加你的 notebook 链接）_

# %%
# 示例代码
import numpy as np
import matplotlib.pyplot as plt

print('环境配置成功！')
