# %% [markdown]
# # DeepLearning Notebooks 导航
#
# 欢迎使用本深度学习示例仓库！
#
# ## 快速开始
#
# 选择你喜欢的方式：
# - 🚀 [在 Binder 中运行](https://mybinder.org/v2/gh/ICEY4040727/DeepLearning/master)
# - 📓 [在 Colab 中打开](https://colab.research.google.com/github/ICEY4040727/DeepLearning/blob/master/)
# - 📖 [用 nbviewer 查看](https://nbviewer.org/github/ICEY4040727/DeepLearning/tree/master/notebooks/)
#
# ## Notebook 列表
#
# ### 预备知识
# - [01_环境测试](预备知识/01_环境测试.ipynb) - 环境配置验证
# - [2.1.1入门](预备知识/2-1数据操作_2.3线性代数/2.1.1入门.ipynb)
# - [2.1.2运算符](预备知识/2-1数据操作_2.3线性代数/2.1.2运算符.ipynb)
# - [2.1.3广播机制](预备知识/2-1数据操作_2.3线性代数/2.1.3广播机制.ipynb)
# - [2.1.4索引和切片](预备知识/2-1数据操作_2.3线性代数/2.1.4索引和切片.ipynb)
# - [2.1.5节省内存](预备知识/2-1数据操作_2.3线性代数/2.1.5节省内存.ipynb)
# - [2.1.6转换为其他python对象](预备知识/2-1数据操作_2.3线性代数/2.1.6转换为其他python对象.ipynb)
# - [2.2.1数据预处理](预备知识/2-1数据操作_2.3线性代数/2.2.1数据预处理.ipynb)
# - [2.3线性代数](预备知识/2-1数据操作_2.3线性代数/2.3线性代数.ipynb)
#
# ## 本地运行
#
# 见 [README.md](../README.md) 的安装说明。

# %%
# 环境测试代码
import numpy as np
import torch
import matplotlib.pyplot as plt

print('numpy 版本:', np.__version__)
print('torch 版本:', torch.__version__)
print('环境配置成功！')

# %% [markdown]
# ## 使用说明
#
# 1. **在线运行**：点击上方 Binder 或 Colab 链接，在浏览器中直接运行
# 2. **本地运行**：克隆仓库后，使用 `pip install -r requirements.txt` 安装依赖
# 3. **查看 HTML**：访问 [GitHub Pages](https://ICEY4040727.github.io/DeepLearning/) 查看静态版本
